# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from numpy.random import randn
np.random.seed(123)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv',index_col=0)

# %%
df
# Out:
#                                School Name School Level  \
# School DBN
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8
# 01M140              P.S. 140 Nathan Straus          K-8
# 01M140              P.S. 140 Nathan Straus          K-8
# ...                                    ...          ...
# 84X717                Icahn Charter School          K-8
# 84X717                Icahn Charter School          K-8
# 84X717                Icahn Charter School          K-8
# 84X717                Icahn Charter School          K-8
# 84X717                Icahn Charter School          K-8
#
#                            Regents Exam  Year  Total Tested Mean Score  \
# School DBN
# 01M034              Common Core Algebra  2017             4          s
# 01M034               Living Environment  2015            16       77.9
# ...

# %%
df.describe()
# Out:
#                 Year   Total Tested
# count  212331.000000  212331.000000
# mean     2015.956069      49.364200
# std         0.799726      93.023576
# min      2015.000000       1.000000
# 25%      2015.000000       5.000000
# 50%      2016.000000      20.000000
# 75%      2017.000000      57.000000
# max      2017.000000    1729.000000

# %%
df.tail()
# Out:
#                      School Name School Level                 Regents Exam  \
# School DBN
# 84X717      Icahn Charter School          K-8           Living Environment
# 84X717      Icahn Charter School          K-8           Living Environment
# 84X717      Icahn Charter School          K-8           Living Environment
# 84X717      Icahn Charter School          K-8           Living Environment
# 84X717      Icahn Charter School          K-8  U.S. History and Government
#
#             Year  Total Tested Mean Score Number Scoring Below 65  \
# School DBN
# 84X717      2016             8          s                       s
# 84X717      2016             5          s                       s
# 84X717      2017             6          s                       s
# 84X717      2017             4          s                       s
# 84X717      2015             1          s                       s
#
#            Percent Scoring Below 65 Number Scoring 65 or Above  \
# School DBN
# ...

# %%
df.shape
# Out:
# (212331, 14)

# %%
df =df.drop_duplicates()

# %%
df.head(10)
# Out:
#                                School Name School Level         Regents Exam  \
# School DBN
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8  Common Core Algebra
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8   Living Environment
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8   Living Environment
# 01M140              P.S. 140 Nathan Straus          K-8  Common Core Algebra
# 01M140              P.S. 140 Nathan Straus          K-8  Common Core Algebra
# 01M140              P.S. 140 Nathan Straus          K-8   Living Environment
# 01M140              P.S. 140 Nathan Straus          K-8   Living Environment
# 01M140              P.S. 140 Nathan Straus          K-8   Living Environment
# 01M184                P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 01M184                P.S. 184m Shuang Wen          K-8  Common Core Algebra
#
#             Year  Total Tested Mean Score Number Scoring Below 65  \
# School DBN
# ...

# %%
#Count after removing duplicates
df.count()
# Out:
# School Name                    188333
# School Level                   188333
# Regents Exam                   188323
# Year                           188333
# Total Tested                   188333
# Mean Score                     188333
# Number Scoring Below 65        188333
# Percent Scoring Below 65       188333
# Number Scoring 65 or Above     188333
# Percent Scoring 65 or Above    188333
# Number Scoring 80 or Above     188333
# Percent Scoring 80 or Above    188333
# Number Scoring CR              188333
# Percent Scoring CR             188333
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# School Name                     0
# School Level                    0
# Regents Exam                   10
# Year                            0
# Total Tested                    0
# Mean Score                      0
# Number Scoring Below 65         0
# Percent Scoring Below 65        0
# Number Scoring 65 or Above      0
# Percent Scoring 65 or Above     0
# Number Scoring 80 or Above      0
# Percent Scoring 80 or Above     0
# Number Scoring CR               0
# Percent Scoring CR              0
# dtype: int64

# %%
df = df.dropna()

# %%
#Count after removing N/A
df.count()
# Out:
# School Name                    188323
# School Level                   188323
# Regents Exam                   188323
# Year                           188323
# Total Tested                   188323
# Mean Score                     188323
# Number Scoring Below 65        188323
# Percent Scoring Below 65       188323
# Number Scoring 65 or Above     188323
# Percent Scoring 65 or Above    188323
# Number Scoring 80 or Above     188323
# Percent Scoring 80 or Above    188323
# Number Scoring CR              188323
# Percent Scoring CR             188323
# dtype: int64

# %% [markdown]
# # Which year has the most schools tested?

# %%
#Statistics of total tested for each year
df.groupby(['Year'])['Total Tested'].count()
# Out:
# Year
# 2015    65356
# 2016    66339
# 2017    56628
# Name: Total Tested, dtype: int64

# %%
#Histogram for total tested by year
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Year'}>,
#         <AxesSubplot:title={'center':'Total Tested'}>]], dtype=object)

# %%
#Histogram plot for year and total tested
df.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Filtering out Year, Name, Exam Score and Total Tested.
df2=df[['Year','School Name','Regents Exam','Mean Score', 'Total Tested']]

# %%
#Filter results
df2.head(25)
# Out:
#             Year                     School Name           Regents Exam  \
# School DBN
# 01M034      2017  P.S. 034 Franklin D. Roosevelt    Common Core Algebra
# 01M034      2015  P.S. 034 Franklin D. Roosevelt     Living Environment
# 01M034      2016  P.S. 034 Franklin D. Roosevelt     Living Environment
# 01M140      2016          P.S. 140 Nathan Straus    Common Core Algebra
# 01M140      2017          P.S. 140 Nathan Straus    Common Core Algebra
# 01M140      2015          P.S. 140 Nathan Straus     Living Environment
# 01M140      2016          P.S. 140 Nathan Straus     Living Environment
# 01M140      2017          P.S. 140 Nathan Straus     Living Environment
# 01M184      2015            P.S. 184m Shuang Wen    Common Core Algebra
# 01M184      2016            P.S. 184m Shuang Wen    Common Core Algebra
# 01M184      2017            P.S. 184m Shuang Wen    Common Core Algebra
# 01M184      2017            P.S. 184m Shuang Wen     Living Environment
# ...

# %%
#New statistics for Orchard Academy
orchard_academy = df2['School Name'] =='Orchard Collegiate Academy'
total_tested = df2['Total Tested'] =='Total Tested'

# %%
df2_orchard_academy =df2[orchard_academy]
df2_orchard_academy.shape
# Out:
# (299, 5)

# %% [markdown]
# # Which year did Orchard Academy have the lowest total tested?

# %%
#Statistics showing total tested by year for Orchard Academy
df2_orchard_academy.groupby(['Year'])['Total Tested'].count()
# Out:
# Year
# 2015    119
# 2016    100
# 2017     80
# Name: Total Tested, dtype: int64

# %%
#Histogram for total tested by year at Orchard Academy
df2_orchard_academy.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Year'}>,
#         <AxesSubplot:title={'center':'Total Tested'}>]], dtype=object)

# %% [markdown]
# # Which Regent Exam has the highest Total Tested amount?

# %%
#Grouping of Regents Exam and totals
df2.groupby(['Regents Exam'])['Total Tested'].count()
# Out:
# Regents Exam
# Algebra2/Trigonometry               8639
# Common Core Algebra                26196
# Common Core Algebra2                6670
# Common Core English                17639
# Common Core Geometry               13512
# English                             9749
# Geometry                            6827
# Global History and Geography       18268
# Integrated Algebra                  9462
# Living Environment                 23528
# Physical Settings/Chemistry         9865
# Physical Settings/Earth Science    14249
# Physical Settings/Physics           4675
# U.S. History and Government        19044
# Name: Total Tested, dtype: int64

# %% [markdown]
# # Which year did Living Environment have the lowest total tested amount.

# %%
plt.figure(figsize=(10,6))

# %%
df_sorted=df.sort_values('Regents Exam')

# %%
#Bargraph showing total regents exams tested by year
plt.figure(figsize=[15,15])
sns.barplot(x='Year', y='Total Tested',hue='Regents Exam',data = df2_orchard_academy)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total Tested'>
